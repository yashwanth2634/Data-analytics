# %% [markdown]
# # M.yashwanth
# # 2211cs010353
# # Analysing govt dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Prison_Population_For_the_Month_of_April_2023_0.csv")

# %%
print(df.columns)
# Out:
# Index(['Sl. No.', 'Name of the Prison', 'Under Trail Prisoners ',
#        'Convict Prisoners', 'Total'],
#       dtype='object')

# %%
df
# Out:
#    Sl. No.                Name of the Prison  Under Trail Prisoners   \
# 0        1         Central Prison, Bengaluru                  4280.0
# 1        2          Open Prison, Devanahalli                     0.0
# 2        3       District Prison, Ramanagara                   303.0
# 3        4            District Prison, Kolar                   148.0
# 4        5            Taluka  Prison, K.G.F.                    79.0
# 5        6         District Prison, Tumakuru                   427.0
# 6        7            Taluka  Prison, Tiptur                     0.0
# 7        8  District Prison, Chikkaballapura                   228.0
# 8        9       Taluka  Prison, Chinthamani                    76.0
# 9       10            Central Prison, Mysuru                   456.0
# 10      11        Taluka  Prison, K.R. Nagar                    76.0
# 11      12         Taluka  Prison, Nanjangud                    41.0
# 12      13    District Prison, Chamarajnagar                   157.0
# ...

# %%
df_cleaned = df.dropna().copy()

# %%
df.columns = df.columns.str.strip()

# %%
sns.set_style("whitegrid")

# %%
df_cleaned.head()
# Out:
#   Sl. No.           Name of the Prison  Under Trail Prisoners   \
# 0       1    Central Prison, Bengaluru                  4280.0
# 1       2     Open Prison, Devanahalli                     0.0
# 2       3  District Prison, Ramanagara                   303.0
# 3       4       District Prison, Kolar                   148.0
# 4       5       Taluka  Prison, K.G.F.                    79.0
#
#    Convict Prisoners   Total
# 0             1129.0  5409.0
# 1               48.0    48.0
# 2                1.0   304.0
# 3                2.0   150.0
# 4                0.0    79.0

# %%
print(df.columns.tolist())
# Out:
# ['Sl. No.', 'Name of the Prison', 'Under Trail Prisoners', 'Convict Prisoners', 'Total']

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=df_cleaned, x="Total", y="Name of the Prison")
plt.title("Total Prisoners per Prison")
plt.xlabel("Total Prisoners")
plt.ylabel("Prison Name")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df_cleaned, x="Under Trail Prisoners ", y="Convict Prisoners")
plt.title("Under-trial vs Convict Prisoners")
plt.xlabel("Under-trial Prisoners")
plt.ylabel("Convict Prisoners")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df_cleaned["Total"], bins=10, kde=True)
plt.title("Distribution of Total Prisoners")
plt.xlabel("Total Prisoners")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.boxplot(y=df_cleaned["Under Trail Prisoners "])
plt.title("Boxplot of Under-trial Prisoners")
plt.ylabel("Number of Under-trial Prisoners")
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.boxplot(y=df_cleaned["Convict Prisoners"])
plt.title("Boxplot of Convict Prisoners")
plt.ylabel("Number of Convict Prisoners")
plt.show()

# %%
plt.figure(figsize=(8, 8))
df_cleaned.groupby("Name of the Prison")["Total"].sum().plot.pie(autopct='%1.1f%%')
plt.title("Total Prisoners Distribution")
plt.ylabel("")
plt.show()

# %%
top_10_prisons = df_cleaned.nlargest(10, "Total")
plt.figure(figsize=(12, 6))
sns.barplot(data=top_10_prisons, x="Total", y="Name of the Prison")
plt.title("Top 10 Prisons with Highest Prisoners")
plt.xlabel("Total Prisoners")
plt.ylabel("Prison Name")
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.heatmap(df_cleaned[["Under Trail Prisoners ", "Convict Prisoners", "Total"]].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df_cleaned["Under Trail Prisoners "], kde=True)
plt.title("Distribution of Under-trial Prisoners")
plt.xlabel("Under-trial Prisoners")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df_cleaned["Convict Prisoners"], kde=True)
plt.title("Distribution of Convict Prisoners")
plt.xlabel("Convict Prisoners")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df_cleaned, x="Under Trail Prisoners ", y="Total")
plt.title("Under-trial vs Total Prisoners")
plt.xlabel("Under-trial Prisoners ")
plt.ylabel("Total Prisoners")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df_cleaned, x="Convict Prisoners", y="Total")
plt.title("Convict Prisoners vs Total Prisoners")
plt.xlabel("Convict Prisoners")
plt.ylabel("Total Prisoners")
plt.show()

# %%
plt.figure(figsize=(6, 6))
df_cleaned[["Under Trail Prisoners ", "Convict Prisoners"]].sum().plot.pie(autopct='%1.1f%%')
plt.title("Under-trial vs Convict Prisoners Percentage")
plt.ylabel("")
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.boxplot(y=df_cleaned["Total"])
plt.title("Boxplot of Total Prisoners")
plt.ylabel("Total Prisoners")
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.stripplot(data=df_cleaned, x="Total", y="Name of the Prison", jitter=True)
plt.title("Total Prisoners per Prison (Strip Plot)")
plt.xlabel("Total Prisoners")
plt.ylabel("Prison Name")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.swarmplot(y=df_cleaned["Under Trail Prisoners "])
plt.title("Swarm Plot of Under-trial Prisoners")
plt.ylabel("Under-trial Prisoners ")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.swarmplot(y=df_cleaned["Convict Prisoners"])
plt.title("Swarm Plot of Convict Prisoners")
plt.ylabel("Convict Prisoners")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(y=df_cleaned["Under Trail Prisoners "])
plt.title("Violin Plot of Under-trial Prisoners ")
plt.ylabel("Under-trial Prisoners ")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(y=df_cleaned["Convict Prisoners"])
plt.title("Violin Plot of Convict Prisoners")
plt.ylabel("Convict Prisoners")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(y=df_cleaned["Total"])
plt.title("Violin Plot of Total Prisoners")
plt.ylabel("Total Prisoners")
plt.show()
